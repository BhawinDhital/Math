# %% [markdown]
# ### Image, Audio and Video with Jupyter Notebook

# %%
# Import the following packages 
from IPython.display import Audio, Video, Image, YouTubeVideo
id = 'GUV6BJ5MGqE'#URL id in youtube
YouTubeVideo(id=id, width=1000,height=400)# You can change width and height to display

# %% [markdown]
# ![](ful.jpg)

# %%
img_path = '/Users/bhawin/Data_Science/Math/ful.jpg'
Image(img_path,width=500, height=200)

# %%
# Get the audio file
audio_link = '/Users/bhawin/Data_Science/Math/kp.wav'

# %%
# Play using Audio
Audio(data=audio_link, autoplay = False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Get the video file
video_link = '/Users/bhawin/Data_Science/Math/kpoli.wav'

# %%
from IPython.display import Video
Video('/Users/bhawin/Data_Science/Math/kpoli.mp3')
# Out:
# <video src="/Users/bhawin/Data_Science/Math/kpoli.mp3" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
# %%HTML
# <video width=400 controls>
#   <source src="kpoli.wav" type="video/wav">
# </video>
# Out:
# <video width=400 controls>
#   <source src="kpoli.wav" type="video/wav">
# </video>

# %% [markdown]
# ![](mv2.gif)

# %% [markdown]
# ![](3p61.gif)
